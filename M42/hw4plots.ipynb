# %%
import matplotlib.pyplot as plt

# %%
pigs = [40, 45, 53, 56, 56, 57, 58, 62, 64, 73,
        74, 79, 78, 80, 81, 81, 81, 82, 83, 83,
        84, 85, 89, 90, 91, 92, 92, 97, 99, 99,
        99, 99, 101, 102, 102, 102, 103, 104, 107, 108,
        109, 113, 114, 118, 121, 123, 126, 128, 137, 138,
        134, 144, 145, 147, 156, 162, 174, 174, 179, 184,
        191, 198, 208, 214, 247, 249, 328, 383, 403, 511]

# %%
len(pigs)
# Out:
# 70

# %%
plt.style.use('ggplot')
plt.hist(pigs, bins = 30, color = 'green')
plt.xlabel('Days')
plt.ylabel('Frequency')
plt.title('Guinea Pig Survival Times',
          fontweight = "bold")
plt.savefig("pigs.jpg", dpi = 400)
plt.show()

# %%
cereal = [16.22, 15.79, 16.03, 15.76, 15.72, 15.89, 16.25, 15.88, 15.89, 15.62,
          15.95, 15.89, 15.99, 16.03, 15.94, 16.29, 16.06, 16.17, 15.97, 16.16,
          16.14, 16.00, 16.16, 15.96, 15.89, 16.08, 15.94, 15.96, 16.08, 16.06,
          16.17, 16.18, 16.10, 15.98, 16.17, 15.93, 15.87, 15.92, 16.03, 16.05,
          15.98, 15.99, 15.92, 16.22, 16.25, 15.64, 16.03, 16.05, 16.26, 16.14]

# %%
len(cereal)
# Out:
# 50

# %%
plt.style.use('ggplot')
plt.hist(cereal, bins = 7, color = 'blue')
plt.xlabel('Weights (ounces)')
plt.ylabel('Frequency')
plt.title('Weights of Cereal Boxes',
          fontweight = "bold")
plt.savefig("cereal.jpg", dpi = 400)
plt.show()

# %%
viewers = [9.8, 8.5, 7.9, 9.3, 9.7, 8.5, 8.7, 8.8, 8.1, 8.2,
           10.2, 9, 8.5, 10.8, 9.6, 9.2, 9.8, 9, 10.7, 9.1,
           9.6, 8.6, 10.2, 9.9, 9.8]

# %%
len(viewers)
# Out:
# 25

# %%
plt.style.use('ggplot')
plt.hist(viewers, bins = 10, color = 'purple')
plt.xlabel('Number of viewers (millions)')
plt.ylabel('Frequency')
plt.title('Viewers of second season of X-Files',
          fontweight = "bold")
plt.savefig("viewers.jpg", dpi = 400)
plt.show()

# %%
twoseas = [7.4, 6.4, 8.1, 9, 10.7, 6.9, 6.4, 7.7, 9.1, 9.6, 6.8, 6.2,
           7.4, 8.6, 10.2, 5.9, 6.8, 8.3, 9.9, 9.8, 6.2, 7.2,
        9.8, 8.5, 7.9, 5.6, 6.8, 9.3, 9.7, 8.5, 5.6,
           5.8, 8.7, 8.8, 8.1, 6.2, 7.1, 8.2, 10.2, 9, 6.1, 7.2, 8.5,
           10.8, 9.6, 5.1, 7.5, 9.2, 9.8]

# %%
len(twoseas)
# Out:
# 49

# %%
plt.style.use('ggplot')
plt.hist(twoseas, bins = 15, color = 'red')
plt.xlabel('Number of viewers (millions)')
plt.ylabel('Frequency')
plt.title('Viewers of first two seasons of X-Files',
          fontweight = "bold")
plt.savefig("twosea.jpg", dpi = 400)
plt.show()

# %%
def counts(string):
    d = {}
    for character in string:
        if character not in d:
            d[character] = 1
        else:
            d[character] += 1
    return d

# %%
#counts(pigs)
#counts(cereal)
#counts(viewers)
#counts(twoseas)
